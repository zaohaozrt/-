# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False
# 生成测试数据
x = np.random.randint(0, 40, 30)
y = np.random.randint(0, 40, 30)
z = np.random.randint(0, 40, 30)
# 创建三维坐标系的绘图区域, 并在该区域中绘制3D散点图
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for xx, yy, zz in zip(x, y, z):
    color = 'y'
    if 10 < zz < 20:
        color = '#C71585'
    elif zz >= 20:
        color = '#008B8B'
    ax.scatter(xx, yy, zz, c=color, marker='*', s=160, linewidth=1,edgecolor='black')
ax.set_xlabel('x轴')
ax.set_ylabel('y轴')
ax.set_zlabel('z轴')
ax.set_title('3D散点图', fontproperties='simhei', fontsize=14)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
fig = plt.figure(figsize=(10, 5)) # 创建图
plt.rcParams["font.family"] = "FangSong" # 支持中文显示
plt.ylim(-12, 12) # Y轴取值范围
plt.yticks([-12 + 2 * i for i in range(13)], [-12 + 2 * i for i in range(13)])
# Y轴刻度
plt.xlim(0, 2 * np.pi) # X轴取值范围
plt.xticks([0.5 * i for i in range(14)], [0.5 * i for i in range(14)]) # X轴刻度
plt.title("函数 y = 10 * sin(x) 在[0,2Π]区间的曲线") # 标题
plt.xlabel("X轴") # X轴标签
plt.ylabel("Y轴") # Y轴标签
x, y = [], [] # 用于保存绘图数据，最开始时什么都没有，默认为空
def update(n): # 更新函数
    x.append(n) # 添加X轴坐标
    y.append(10 * np.sin(n)) # 添加Y轴坐标
    plt.plot(x, y, "r--") # 绘制折线图
ani = FuncAnimation(fig, update, frames=np.arange(0, 2 * np.pi, 0.1),
interval=50, blit=False, repeat=False) # 创建动画效果
plt.show() # 显示图片

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
fig, ax = plt.subplots() # 创建画布和绘图区
ax.set_axis_off() # 不显示坐标轴
x = np.arange(0, 2 * np.pi, 0.01) # 生成X轴坐标序列
line1, = ax.plot(x, np.sin(x)) # 获取折线图对象，逗号不可少，如果没有逗号，得到的是元组
line2, = ax.plot(x, np.cos(x)) # 获取折线图对象，逗号不可少
def update(n): # 动态更新函数
    line1.set_ydata(np.sin(x + n / 10.0)) # 改变线条y的坐标值
    line2.set_ydata(np.cos(x + n / 10.0)) # 改变线条y的坐标值
ani = FuncAnimation(fig, update, frames=100, interval=50, blit=False,
repeat=False) # 创建动画效果
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,10,1)
y1=np.exp(x)
y2=np.log(x)
y3=np.square(x)
fig = plt.figure(constrained_layout=True)
gs = fig.add_gridspec(3, 3)
ax_1 = fig.add_subplot(gs[0,:2])
ax_2 = fig.add_subplot(gs[1:, :2])
ax_3 = fig.add_subplot(gs[:, 2])
ax_1.plot(x,y1)
ax_2.plot(x,y2)
ax_3.plot(x,y3)
ax_1.set_xlim(0,10)
ax_2.set_xlim(0,10)
ax_3.set_xlim(0,10)
ax_1.set_title('exp')
ax_2.set_title('log')
ax_3.set_title('square')
plt.show()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation

def update_points(num):
    point_ani.set_data(x[num], y[num])
    text_pt.set_text("x=%.3f, y=%.3f" % (x[num], y[num]))
    return point_ani, text_pt,


x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

fig = plt.figure(tight_layout=True)
plt.plot(x, y)
point_ani, = plt.plot(x[0], y[0], "ro")
plt.grid(ls="--")
text_pt = plt.text(4, 0.8, '', fontsize=16)  # 点的位置以文本形式输出

ani = animation.FuncAnimation(fig, update_points, np.arange(0, 100), interval=100, blit=False)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15300\3171909207.py:7: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   point_ani.set_data(x[num], y[num])

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
plt.rcParams['font.sans-serif'] = ["SimHei"]
fig3 = plt.figure()
gs = fig3.add_gridspec(3,3)
f3_ax1 = fig3.add_subplot(gs[0, :])
f3_ax1.set_title('1')
x1 = np.array([0,1])
y1 = np.array([1,2])
f3_ax1.plot(x1,y1)
f3_ax1.set_yticks([1,2])
f3_ax2 = fig3.add_subplot(gs[1, :-1])
f3_ax2.set_title('2')
f3_ax1.plot(x1,y1)
f3_ax3 = fig3.add_subplot(gs[1:, -1])
f3_ax3.set_title('3')
x3 = np.array([1,2,3,4])
y3 = np.array([1,4,8,12])
f3_ax3.plot(x3,y3)
f3_ax4 = fig3.add_subplot(gs[-1, 0])
f3_ax4.set_title('4')
x2 = np.array([0,0.5,1])
y2 = np.array([0,2,3])
f3_ax4.scatter(x2,y2)
f3_ax5 = fig3.add_subplot(gs[-1, -2])
f3_ax5.set_title('5')
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
plt.rcParams['font.sans-serif'] = ["SimHei"]
x1 = np.linspace(-np.pi, np.pi, 100, endpoint=True)
y1 = np.sin(x1)
ax1 = plt.subplot2grid((2, 3), (0,2))
ax1.plot(x1,y1)
ax1.set_xticks([-2.5,0,2.5])
ax1.set_yticks([-1,0,1])
y2 = np.cos(x1)
ax2 = plt.subplot2grid((2, 3), (1,2), sharex=ax1)
ax2.plot(x1,y2)
ax2.set_yticks([-1,0,1])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1)
plt.show()

# %%
# 大数据202王申政 2029730224
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

x = np.arange(0,10)
y1 = np.exp(x)
y2 = np.log(x)
y3 = np.square(x)

# 创建画布和布局
fig = plt.figure(constrained_layout=True)
gs = fig.add_gridspec(3, 3)
ax_one = fig.add_subplot(gs[0, :-1])
ax_two = fig.add_subplot(gs[1:, :-1])
ax_thr = fig.add_subplot(gs[0:, -1])
# 第1个子图
ax_one.plot(x, y1)
ax_one.set_title('exp')
# 第2个子图
ax_two.plot(x,y2)
ax_two.set_title('log')
ax_two.set_yticks([0 + 0.5 * i for i in range(5)],[0 + 0.5 * i for i in range(5)])
# 第3个子图
ax_thr.plot(x,y3)
ax_thr.set_title('square')
ax_thr.set_yticks([0 + 10 * i for i in range(9)],[0 + 10 * i for i in range(9)])
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15300\2715996479.py:10: RuntimeWarning: divide by zero encountered in log
#   y2 = np.log(x)
